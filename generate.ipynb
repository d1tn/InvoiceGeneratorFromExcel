# %%
# 出力する値とセル番地の指定
#     請求書日付
cell_invoiceDate = 'H1'
#     請求書No.
cell_invoiceNo = 'H2'
#     宛先（相手先）
cell_toName = 'A6'
#     受注No.
cell_orderNo = ''
#     合計請求額
cell_sumPrice = 'G28'
#     お振込み期限
cell_dueDate = 'B35'




#実装
import pandas as pd
import openpyxl


# 入力値
acceptMonth = '202110'
sheetName='請求一覧2110'
dataRange='A3:H13'


# ワークシートの読込
wb = openpyxl.load_workbook('請求一覧創造太郎.xlsx')
ws = wb[sheetName]
ws_customerTbl = wb['顧客管理テーブル']

# 顧客CDのDF化
customerTbl = []
for row in ws_customerTbl['A2:B100']:
    values = []
    for col in row:
        values.append(col.value)
    customerTbl.append(values)
customerTbl = pd.DataFrame(customerTbl[1:], columns=customerTbl[0])

# 請求一覧をDataFrame化
df = []
for row in ws[dataRange]:
    values = []
    for col in row:
        values.append(col.value)
    df.append(values)
df = pd.DataFrame(df[1:], columns=df[0])

#顧客CDから相手先名と相手先コードを紐づけ
# df['相手先名'] = list(map(lambda x: customerTbl.loc[customerTbl['顧客ＣＤ'] == x ]['顧客名'],list(df['相手先コード'])))
df['相手先名'] = [i.loc[:] for i in [customerTbl.loc[customerTbl['顧客ＣＤ'] == x ]['顧客名'] for x in list(df['相手先コード'])]]

display(df['相手先名'])
# df['相手先名'] = list(map(lambda x: customerTbl.loc[customerTbl['顧客ＣＤ'] == x ]['顧客名'],list(df['相手先コード'])))

display(df)

# 重複のない相手先リストを作成
df_customer = df['相手先コード'].dropna().astype(int)
customerList = []
for i in df_customer:
    if i not in customerList:
        customerList.append(i)

for i in customerList:
    customer = df[df['相手先コード']== i ]
    display(customer)
        

print(customerList)

display(df)
display(customerList)


res["アイテム名"] = list(map(
    lambda x : itemData.loc[itemData["ItemId"] == x]["Name"].item(),list(res["アイテムID"])
))
# Out:
# 0        9    株式会社クスダ製作所
# Name: 顧客名, dtype: object
# 1      12    学校法人　さくら学園
# Name: 顧客名, dtype: object
# 2    6    NGCネットワークス株式会社
# Name: 顧客名, dtype: object
# 3        1    株式会社サンワテック
# Name: 顧客名, dtype: object
# 4    0    アデックテクノロジー株式会社
# Name: 顧客名, dtype: object
# 5      12    学校法人　さくら学園
# Name: 顧客名, dtype: object
# 6    0    アデックテクノロジー株式会社
# Name: 顧客名, dtype: object
# 7            Series([], Name: 顧客名, dtype: object)
# 8            Series([], Name: 顧客名, dtype: object)
# 9            Series([], Name: 顧客名, dtype: object)
# Name: 相手先名, dtype: object
#     受注No.                                          相手先名  相手先コード  \
# 0  210401      9    株式会社クスダ製作所
# Name: 顧客名, dtype: object  3001.0
# 1  210601    12    学校法人　さくら学園
# Name: 顧客名, dtype: object  4001.0
# 2  210602  6    NGCネットワークス株式会社
# Name: 顧客名, dtype: object  2001.0
# 3  210701      1    株式会社サンワテック
# Name: 顧客名, dtype: object  1002.0
# 4  210702  0    アデックテクノロジー株式会社
# Name: 顧客名, dtype: object  1001.0
# 5  210803    12    学校法人　さくら学園
# ...
